# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../Life Expectancy Data.csv")
print(data.shape)
data.head()
# Out:
# (2938, 22)
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
# ...

# %% [markdown]
# # Strip white spaces from column names

# %% [markdown]
# # Delete 10 rows where life expectancy is missing

# %% [markdown]
# # drop correlated features
#     * under-five deaths/infant deaths
#     * GDP / percentage expenditure
#     * thinness 1-19/thinness 5-9
#     * Schooling / Income composition of resources

# %% [markdown]
# # binarize
#     * HIV / Aids

# %% [markdown]
# # log + 1 transform:
#     * 'under-five deaths '
#     * population
#     * GDP - this one doesnt need the +1
#     * Measles

# %% [markdown]
# # drop columns:
#     * year
#     * country

# %% [markdown]
# # impute

# %% [markdown]
# # Sort by country and year first to ensure interpolation makes sense
# data = data.sort_values(['Country', 'Year'])
#
# # Fill missing values using linear interpolation within each country
# num_cols = data.select_dtypes(include=['float64', 'int64']).columns
# data[num_cols] = data.groupby('Country')[num_cols].transform(lambda x: x.interpolate(limit_direction='both'))

# %% [markdown]
# # windsorization
#     * Adult Mortality
#     * Alcohol
#     * BMI more agressive

# %%
q_limit = data['Adult Mortality'].quantile(0.95)
data['Adult Mortality'] = data['Adult Mortality'].clip(upper=q_limit)

# %%
data[' BMI '] = data[' BMI '].clip(lower=15, upper=65)

# or do nan + interploation as its garbage data
data.loc[(data['BMI'] < 10) | (data['BMI'] > 65)  , 'BMI'] = np.nan

# 2. Use the "Connect the Dots" interpolation by country
data['BMI'] = data.groupby('Country')['BMI'].transform(lambda x: x.interpolate(limit_direction='both'))
# Out:
#   Cell In[10], line 3
#     or do nan + interploation as its garbage data
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # use RobustScaler to better deal with remaining outliers

# %% [markdown]
# # country converter to see continents

# %% [markdown]
# # check if vaccines are correlated
